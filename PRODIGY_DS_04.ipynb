# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\kiran\Downloads\twitter_training.csv")

# %%
df.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df.tail()
# Out:
#        2401 Borderlands  Positive  \
# 74676  9200      Nvidia  Positive
# 74677  9200      Nvidia  Positive
# 74678  9200      Nvidia  Positive
# 74679  9200      Nvidia  Positive
# 74680  9200      Nvidia  Positive
#
#       im getting on borderlands and i will murder you all ,
# 74676  Just realized that the Windows partition of my...
# 74677  Just realized that my Mac window partition is ...
# 74678  Just realized the windows partition of my Mac ...
# 74679  Just realized between the windows partition of...
# 74680  Just like the windows partition of my Mac is l...

# %%
col_names=['ID','Entity','Sentiment','Content']
df1 = pd.read_csv(r"C:\Users\kiran\Downloads\twitter_training.csv",names=col_names)

# %%
df1.head()
# Out:
#      ID       Entity Sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                              Content
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of          ID       Entity Sentiment  \
# 0      2401  Borderlands  Positive
# 1      2401  Borderlands  Positive
# 2      2401  Borderlands  Positive
# 3      2401  Borderlands  Positive
# 4      2401  Borderlands  Positive
# ...     ...          ...       ...
# 74677  9200       Nvidia  Positive
# 74678  9200       Nvidia  Positive
# 74679  9200       Nvidia  Positive
# 74680  9200       Nvidia  Positive
# 74681  9200       Nvidia  Positive
#
#                                                  Content
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# ...

# %%
df1.shape
# Out:
# (74682, 4)

# %%
df1.isnull().sum()
# Out:
# ID             0
# Entity         0
# Sentiment      0
# Content      686
# dtype: int64

# %%
df1.dropna(axis=0 , inplace=True)

# %%
df1.isnull().sum()
# Out:
# ID           0
# Entity       0
# Sentiment    0
# Content      0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 2340

# %%
df1.drop_duplicates(inplace=True)
df1.duplicated().sum()
# Out:
# 0

# %%
sentiment_counts = df1['Sentiment'].value_counts()
sentiment_counts
# Out:
# Sentiment
# Negative      21698
# Positive      19713
# Neutral       17708
# Irrelevant    12537
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 3))
sentiment_counts.plot(kind='bar')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Number of Tweets')
plt.xticks(rotation=0)
plt.show()

# %%
brand_data = df1[df1['Entity'].str.contains('Amazon', case=False)]
brand_sentiment_counts = brand_data['Sentiment'].value_counts()
brand_sentiment_counts
# Out:
# Sentiment
# Neutral       1197
# Negative       565
# Positive       302
# Irrelevant     185
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_sentiment_counts, labels=brand_sentiment_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution for Amazon')
plt.show()

# %%
brand_data1 = df1[df1['Entity'].str.contains('Google', case=False)]
brand_sentiment_counts1 = brand_data1['Sentiment'].value_counts()
brand_sentiment_counts1
# Out:
# Sentiment
# Neutral       785
# Negative      570
# Irrelevant    505
# Positive      339
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_sentiment_counts1, labels=brand_sentiment_counts1.index, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution for Google')
plt.show()

# %%
brand_data2 = df1[df1['Entity'].str.contains('Microsoft', case=False)]
brand_sentiment_counts2 = brand_data2['Sentiment'].value_counts()
brand_sentiment_counts2
# Out:
# Sentiment
# Neutral       816
# Negative      748
# Positive      573
# Irrelevant    167
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_sentiment_counts2, labels=brand_sentiment_counts1.index, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution for Microsoft')
plt.show()

# %%
brand_data3 = df1[df1['Entity'].str.contains('Nvidia', case=False)]
brand_sentiment_counts3 = brand_data3['Sentiment'].value_counts()
brand_sentiment_counts3
# Out:
# Sentiment
# Neutral       848
# Positive      761
# Negative      503
# Irrelevant     86
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 6))
plt.pie(brand_sentiment_counts3, labels=brand_sentiment_counts1.index, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution for Nvidia')
plt.show()
